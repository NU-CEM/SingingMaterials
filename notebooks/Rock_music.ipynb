# %% [markdown]
# # Rock Music

# %% [markdown]
# <img src="../assets/img/rock_music.png" width="750" align="center">

# %% [markdown]
# The interesting rocks (from a sonification-dos perspective) are:
#
# - ZnS (well defined, relative low frequency peaks): mp-10695
# - CaCO3 (localised "ringer" modes from the carbon): mp-3953
# - Polymorph comparisons:
#     - SiO2 Stishovite : mp-6947
#     - SiO2 Christolobite: mp-546794
#     - SiO2 Quartz: mp-6930
# - CaSO4 Anhydrite (ringers): mp-4406
# - FeS2, pyrite (soft): mp-1522
# - Diamond (hard, high freq): mp-66
# - Barium zirconate (soft, low freq): mp-3834

# %%
# 1. Import
import sys
sys.path.append('../')
from phonon_sonification import data_interface, visualisation

# %%
stishovite_data = mp_interface.dos_stats_analysis("mp-6947",temp=[0,50,100,150,200,250,300,350,400,450])
# Out:
# cannot calculate stats for 0K
# Fetching from existing file...

# %%
visualisation.plot_dos_at_temperature(stishovite_data)
# Out:
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %%
from IPython.display import HTML

anim = visualisation.animate_dos_vs_temperature(stishovite_data)
HTML(anim.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from IPython.display import HTML
#       2
# ----> 3 anim = visualisation.animate_dos_vs_temperature(stishovite_data)
#       4 HTML(anim.to_jshtml())
#
# NameError: name 'stishovite_data' is not defined

# %% [markdown]
# # Calcium carbonate (calcite, aragonite)

# %%
CaCO3_data = mp_interface.dos_stats_analysis("mp-3953",temp=[300,350,400,450,500,550,600,650,700,750,800])
visualisation.plot_dos_at_temperature(CaCO3_data,T=300)
# Out:
# Fetching from existing file...
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %%
visualisation.plot_dos_at_temperature(CaCO3_data)
# Out:
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %%
import mp_api
from mp_api.client import MPRester
import ase
from ase.visualize import view
import os
from dotenv import load_dotenv
load_dotenv () # use python-dotenv library for storing secrets in a .env file in project route (or at another path that is specified here)


with MPRester(os.getenv('MP_API_KEY')) as mpr:
    structure = mpr.get_structure_by_material_id("mp-3953")  # Example: Silicon

# Convert Pymatgen Structure to ASE Atoms Object
ase_structure = structure.to_ase_atoms()
view(ase_structure*[3,3,3], viewer='x3d')
# Out:
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 83.437544025">
#     <group/>
#   </viewpoint>
#   <transform translation="-6.876535485 -6.281321385 -9.537554715">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
# ...

# %% [markdown]
# See interactive structure with bonds here:[https://next-gen.materialsproject.org/materials/mp-3953](https://next-gen.materialsproject.org/materials/mp-3953)

# %%
graphene_data = data_interface.dos_stats_analysis(phonopy_filename = "../phonon_sonification/phonopy_graphene.yaml")
visualisation.plot_dos_at_temperature(graphene_data)
# Out:
# There are 170 imaginary frequencies which have not been processed
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %%
diamond_data = data_interface.dos_stats_analysis(mp_id = "mp-66")
visualisation.plot_dos_at_temperature(diamond_data)
# Out:
# Fetching from Materials Project servers...
# There are 3 imaginary frequencies which have not been processed
# bin width is 0.02997924580000634 THz
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %%
quartz_data = data_interface.dos_stats_analysis(mp_id = "mp-6930")
visualisation.plot_dos_at_temperature(quartz_data)
# Out:
# Fetching from existing file...
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %%
salt_data = data_interface.dos_stats_analysis(mp_id = "mp-22862")
visualisation.plot_dos_at_temperature(salt_data)
# Out:
# Fetching from Materials Project servers...
# There are 3 imaginary frequencies which have not been processed
# bin width is 0.02997924580000634 THz
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %%
import sys
sys.path.append('../')
from phonon_sonification import visualisation, phonon_dos_sonifier

# %% [markdown]
# # STO

# %%
soni = phonon_dos_sonifier.PhononDOSSonifier("mp-4651")
visualisation.plot_dos_at_temperature(soni.dos_dict)
# Out:
# Finding phonon DOS data for mp-4651...
# Fetching from Materials Project servers...
# There are 68 imaginary frequencies which have not been processed
# bin width is 0.029979245800006483 THz
# Phonon frequency minimum  (data extracted): 2.18e+10 Hz
# Phonon frequency maximum  (data extracted): 2.72e+13 Hz
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %%
soni.get_site_stats('O_1')
# Out:
# {'band_centre': np.float64(13494518336641.605),
#  'integrated_dos': np.float64(2999999877222.173),
#  'quantile_25': np.float64(8629595312095.783),
#  'quantile_75': np.float64(17026660032884.352),
#  'IQR': np.float64(8397064720788.568),
#  'shannon_entropy': np.float64(-6.078779766993881),
#  'densities': array([3.73666284e-06, 8.19074507e-06, 1.65085122e-05, 3.06418843e-05,
#         5.24255963e-05, 8.27553188e-05, 1.20766736e-04, 1.63660754e-04,
#         2.07714763e-04, 2.50273875e-04, 2.91539513e-04, 3.34691921e-04,
#         3.83848242e-04, 4.40976069e-04, 5.03803047e-04, 5.66144577e-04,
#         6.20389181e-04, 6.60481858e-04, 6.83671841e-04, 6.90447360e-04,
#         6.83403384e-04, 6.66236400e-04, 6.43491875e-04, 6.20787908e-04,
#         6.04710632e-04, 6.01658240e-04, 6.15535698e-04, 6.45187007e-04,
#         6.83276750e-04, 7.18142581e-04, 7.38519491e-04, 7.38859967e-04,
#         7.22041470e-04, 6.97657138e-04, 6.76948006e-04, 6.67524659e-04,
# ...

# %% [markdown]
# # PbTe

# %%
soni = phonon_dos_sonifier.PhononDOSSonifier("mp-19717")
visualisation.plot_dos_at_temperature(soni.dos_dict)
# Out:
# Finding phonon DOS data for mp-19717...
# Fetching from Materials Project servers...
# There are 3 imaginary frequencies which have not been processed
# bin width is 0.02997924580000634 THz
# Phonon frequency minimum  (data extracted): 1.76e+10 Hz
# Phonon frequency maximum  (data extracted): 4.27e+12 Hz
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %%
soni.get_site_stats('Te_1')
# Out:
# {'band_centre': np.float64(2604852120142.453),
#  'integrated_dos': np.float64(2999994750965.7183),
#  'quantile_25': np.float64(2369222600000.3403),
#  'quantile_75': np.float64(3010861205287.257),
#  'IQR': np.float64(641638605286.9165),
#  'shannon_entropy': np.float64(-4.2565053788482405),
#  'densities': array([1.35266124e-04, 2.63477052e-04, 4.83019060e-04, 8.35353461e-04,
#         1.36740229e-03, 2.12736725e-03, 3.16045639e-03, 4.50563686e-03,
#         6.19405650e-03, 8.24937568e-03, 1.06900563e-02, 1.35334688e-02,
#         1.68013982e-02, 2.05263300e-02, 2.47580323e-02, 2.95705294e-02,
#         3.50706450e-02, 4.14108762e-02, 4.88109140e-02, 5.75914768e-02,
#         6.82165575e-02, 8.13212382e-02, 9.76768520e-02, 1.18037376e-01,
#         1.42854675e-01, 1.71951893e-01, 2.04343956e-01, 2.38388137e-01,
#         2.72285834e-01, 3.04723700e-01, 3.35307431e-01, 3.64509567e-01,
#         3.93083100e-01, 4.21167791e-01, 4.47531493e-01, 4.69439705e-01,
# ...

# %% [markdown]
# # C

# %%
soni = phonon_dos_sonifier.PhononDOSSonifier("mp-66")
visualisation.plot_dos_at_temperature(soni.dos_dict)
# Out:
# Finding phonon DOS data for mp-66...
# Fetching from Materials Project servers...
# There are 3 imaginary frequencies which have not been processed
# bin width is 0.02997924580000634 THz
# Phonon frequency minimum  (data extracted): 1.76e+10 Hz
# Phonon frequency maximum  (data extracted): 4.80e+13 Hz
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # Si

# %%
soni.get_site_stats('C_1')
# Out:
# {'band_centre': np.float64(29291946383474.06),
#  'integrated_dos': np.float64(2999998754947.593),
#  'quantile_25': np.float64(22562636805026.473),
#  'quantile_75': np.float64(36415689487505.19),
#  'IQR': np.float64(13853052682478.715),
#  'shannon_entropy': np.float64(-6.700667068888588),
#  'densities': array([1.93317776e-05, 2.40419480e-05, 2.66806748e-05, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00], shape=(1603,))}

# %%
soni = phonon_dos_sonifier.PhononDOSSonifier("mp-149")
visualisation.plot_dos_at_temperature(soni.dos_dict)
# Out:
# Finding phonon DOS data for mp-149...
# Fetching from Materials Project servers...
# There are 3 imaginary frequencies which have not been processed
# bin width is 0.02997924580000634 THz
# Phonon frequency minimum  (data extracted): 1.76e+10 Hz
# Phonon frequency maximum  (data extracted): 1.85e+13 Hz
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %%
soni.get_site_stats('Si_1')
# Out:
# {'band_centre': np.float64(9889712194508.957),
#  'integrated_dos': np.float64(2999998750030.669),
#  'quantile_25': np.float64(5163274542469.201),
#  'quantile_75': np.float64(14113959855971.559),
#  'IQR': np.float64(8950685313502.357),
#  'shannon_entropy': np.float64(-5.7016458880647125),
#  'densities': array([1.95442194e-05, 2.47268819e-05, 2.86568952e-05, 3.15297685e-05,
#         3.51975014e-05, 4.31316764e-05, 5.94813471e-05, 8.74726845e-05,
#         1.27872909e-04, 1.78452486e-04, 2.35079968e-04, 2.94260069e-04,
#         3.55955305e-04, 4.24971964e-04, 5.09438620e-04, 6.16155829e-04,
#         7.44745981e-04, 8.84538624e-04, 1.01787944e-03, 1.12976771e-03,
#         1.21843568e-03, 1.29931379e-03, 1.39854690e-03, 1.53937803e-03,
#         1.72963782e-03, 1.95769478e-03, 2.19882969e-03, 2.42825761e-03,
#         2.63404689e-03, 2.82332882e-03, 3.01767365e-03, 3.23848134e-03,
#         3.49036106e-03, 3.75532250e-03, 4.00602624e-03, 4.23135492e-03,
# ...

# %% [markdown]
# # BAs

# %%
soni = phonon_dos_sonifier.PhononDOSSonifier("mp-10044")
visualisation.plot_dos_at_temperature(soni.dos_dict)
# Out:
# Finding phonon DOS data for mp-10044...
# Fetching from Materials Project servers...
# There are 3 imaginary frequencies which have not been processed
# bin width is 0.02997924580000634 THz
# Phonon frequency minimum  (data extracted): 1.76e+10 Hz
# Phonon frequency maximum  (data extracted): 2.64e+13 Hz
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # MgO

# %%
soni.get_site_stats('As_1')
# Out:
# {'band_centre': np.float64(7163489716251.639),
#  'integrated_dos': np.float64(2999997821125.485),
#  'quantile_25': np.float64(5175831671151.872),
#  'quantile_75': np.float64(8147225786918.621),
#  'IQR': np.float64(2971394115766.749),
#  'shannon_entropy': np.float64(-5.513225549048464),
#  'densities': array([3.39157003e-05, 4.24722855e-05, 4.80620674e-05, 5.02264439e-05,
#         5.10700568e-05, 5.55232797e-05, 7.03800061e-05, 1.02236255e-04,
#         1.54934000e-04, 2.27595807e-04, 3.14561157e-04, 4.07951035e-04,
#         5.02085440e-04, 5.97474512e-04, 7.01843705e-04, 8.26934882e-04,
#         9.81874362e-04, 1.16590400e-03, 1.36469286e-03, 1.55416722e-03,
#         1.71236941e-03, 1.83397331e-03, 1.93805559e-03, 2.06228232e-03,
#         2.24538541e-03, 2.50802727e-03, 2.84301759e-03, 3.21901040e-03,
#         3.59353398e-03, 3.92802164e-03, 4.20024194e-03, 4.41310915e-03,
#         4.59813770e-03, 4.80822715e-03, 5.09583818e-03, 5.48343823e-03,
# ...

# %%
soni = phonon_dos_sonifier.PhononDOSSonifier("mp-1265")
visualisation.plot_dos_at_temperature(soni.dos_dict)
# Out:
# Finding phonon DOS data for mp-1265...
# Fetching from existing file...
# Phonon frequency minimum  (data extracted): 1.76e+10 Hz
# Phonon frequency maximum  (data extracted): 2.50e+13 Hz
# <module 'matplotlib.pyplot' from '/Users/mynf8/miniconda3/envs/singing_materials_2026/lib/python3.13/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # stiffness
#
# https://www.youtube.com/watch?v=bULWWCIMMz0 C-PbTe-choral 1
# https://www.youtube.com/watch?v=0BBLRzRWe18 PbTe-C-spectral 2.
# https://www.youtube.com/watch?v=f5BH3J3KVaE BAs-STO-choral 1.
# https://www.youtube.com/watch?v=zqZHOvLnz3U BAs-STO-spectra 2 (note difference in sonification).
# https://www.youtube.com/watch?v=aRCqavdzQLk C-PbTe-synth 1
# https://www.youtube.com/watch?v=SDaaVD16BwU Si-STO-spectral  2.
# https://www.youtube.com/watch?v=7nrtZG8vDP0 Si-STO-synth 2.
# https://www.youtube.com/watch?v=xKkiBmfpKps STO-BAS-synth 2.
# https://www.youtube.com/watch?v=Tp_wZMPn2XQ STO-Si-choral 1.
#
# # mass difference
#
# https://www.youtube.com/watch?v=OEwsVXSWObE MgO-BaS-spectral 2.
# https://youtu.be/wQZ3xOy4qN4 BAs-MgO-synth 1.
# https://youtu.be/uGF5DFdnvJU C-STO-synth 2.
# https://youtu.be/-AeTPjeF43Y STO-MgO-choral 1.
# https://youtu.be/ZwB-yQnOCt8 BAs-MgO-choral 1.
# https://youtu.be/t6xaYfLWB1Y MgO-STO-synth 2.
# https://youtu.be/Phgergdjkm8 C-STO-choral 2.
# https://youtu.be/fFi8bO_x-ys MgO-STO-spectral 2
# https://youtu.be/9C00pSXGJPA STO-C-spectral 1.

# %%
soni.get_site_stats('O_1')
# Out:
# {'band_centre': np.float64(13100979990603.695),
#  'integrated_dos': np.float64(2999999011510.1035),
#  'quantile_25': np.float64(11548270374741.203),
#  'quantile_75': np.float64(15335513598980.732),
#  'IQR': np.float64(3787243224239.5293),
#  'shannon_entropy': np.float64(-5.863483162130814),
#  'densities': array([1.53484769e-05, 1.90897920e-05, 2.11926113e-05, 2.10175118e-05,
#         1.86847715e-05, 1.50978323e-05, 1.16789109e-05, 1.00666278e-05,
#         1.19755382e-05, 1.91455260e-05, 3.30859607e-05, 5.44222345e-05,
#         8.20908530e-05, 1.13042648e-04, 1.43011692e-04, 1.68191232e-04,
#         1.86900320e-04, 2.00291885e-04, 2.11925212e-04, 2.26806920e-04,
#         2.50494092e-04, 2.88161502e-04, 3.43050481e-04, 4.14161221e-04,
#         4.94248208e-04, 5.70092386e-04, 6.26467404e-04, 6.52935127e-04,
#         6.49992176e-04, 6.30493499e-04, 6.14852356e-04, 6.22584192e-04,
#         6.64980604e-04, 7.42326243e-04, 8.45745103e-04, 9.61561532e-04,
# ...
